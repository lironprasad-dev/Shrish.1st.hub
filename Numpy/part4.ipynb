# %%
import numpy as np

# %% [markdown]
# # random numbers

# %%
import numpy as np
rand_arr=np.random.rand(4,4)
rand_arr
# Out:
# array([[0.16218828, 0.5075662 , 0.34867793, 0.65634562],
#        [0.42953366, 0.76783144, 0.48352803, 0.19830717],
#        [0.70479416, 0.42579414, 0.12707916, 0.1315965 ],
#        [0.53617376, 0.60303632, 0.16656148, 0.58980041]])

# %%
import numpy as np

ar1=np.random.randint(10,20, size=(3,4))
ar1
# Out:
# array([[17, 14, 16, 15],
#        [14, 16, 19, 19],
#        [17, 16, 16, 10]], dtype=int32)
